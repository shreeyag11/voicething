# %%
import json
from collections import defaultdict

def do_the_thing(files):
    vocab = defaultdict(lambda: defaultdict(lambda: 0))
    probs = defaultdict(lambda: defaultdict(lambda: 0))

    for file in files:
        data = pd.read_csv(file)
        label = file.replace("scratch/", "")
        label = label.replace(".csv", "")

        data['text'] = data['text'].apply(lambda x: x.lower())
         
        for text in data['text']:
            for word in text.split():

                vocab[label][word] += 1

    temp = []
    [temp.extend(list(vocab[label].keys())) for label in vocab.keys()]
    all_words = set(temp)

    labels = vocab.keys()

    for word in all_words:
        sums = 0
        for label in labels:
            sums += vocab[label][word]
        
        for label in labels:
            if sums != 0:
                probs[word][label] = float(vocab[label][word]) / float(sums)
    
    return probs

# %%
import operator

def predict(probs, query):
    labels = probs['13'].keys()

    predictions = defaultdict(lambda: 1)

    for label in labels:
        all_zero = True
        for word in query.split():
            if probs[word][label] != 0:
                predictions[label] *= probs[word][label]
                all_zero = False
        
        if all_zero:
            predictions[label] = 0
    
    predictions = dict(predictions)

    max = 0
    result = ""

    for label, prob in predictions.items():
        if prob > max:
            max = prob
            result = label
        
    return result

# %%
import pandas as pd

files = [
    "scratch/AddToPlaylist.csv",
    "scratch/BookRestaurant.csv",
    "scratch/GetWeather.csv",
    "scratch/PlayMusic.csv",
    "scratch/RateBook.csv",
    "scratch/SearchCreativeWork.csv",
    "scratch/SearchScreeningEvent.csv"
]

probs = do_the_thing(files)
predict(probs, "rate shreeya sanjay gupta's coding skills 9/11")
# Out:
# 'RateBook'

# %%
with open("probs.json", 'w') as out_file:
    json.dump(probs, out_file)

# %%
with open("jsgf", 'w') as out_file:
    out_file.write(f"#JSGF V1.0; grammar words; public <words> = { ' | '.join(list(probs.keys()))}")

# %%
print()
# Out:
# 13 | waiting, | noor | sushis | conan | sacrifice | marching | color | horse | creative | pub | wannabe: | roger | chemistry | 10/4/2021 | fragile | gandhi | wings | attell | anarchy | robbie's | katiejane | racketeers | sonora | tres | umbrian | traitor | neto | mummy | sight | central | sherlock | fayette | mapa | marvin | johnston | joyal | england | cold | wilderville | mercedes | bearmouth | war: | pier | bastian | messengers | sandman | spain | twentieth | kahn | phera | 1966 | sal | olive | politics | westbam | textbook | colder | classic | episodes | conchiglie | koontz | doherty | trolls | mcnevan | limbo | lwin | helix | advocate | bruno | bowers | devil | 01:48:35 | subroc | ford | a | nicodemus | winifred's | mandino | thompsontown | sarkhosh | climax | rim | selections | logic | fifteenth, | harassed | bessie, | nashville: | scouse | unfinished | mclaughlin | palau | brightman | irritating | queens | nicht | arsenault | luckiest | re: | kennedy | karnataki | us | thin | over, | pm | americans | baby-sittor | trancers | skaat | mojito | lexington-fayette | family | body | 37 | xquery | pain | estado | dakus | tomã© | madeleine | fats | mana | clements | brass | mancos | fragments | today? | intel | hamatora | pamela's | trabajo | agatsuma | komuro | shore | 2 | utley | airto | conditions | morgan | emptiness | 09:32:06 | trenton | bring | cleo | farristown | cup | cropper | pavarotti | dvd | coleslaw | anymore | spears | jean-georges | cliffwood | caetano | glenarden | verro | vonda's | unit | manson | roseville | italian-american | victorious | principle | alderwood | salmonella | hate | mystery | sixteenth, | tulsa | archive.is | eunice | potter | casa | claudine | crugers | kokomo | 1953 | serviette | give | talkow | chet | george | guyana | nightcall | coxs | lower | nora | fourteenth | daring | rouge | durant | clã¡sica | cord | texas | dancefloor | palmetto | only, | hutchinson | revoluciã³n | hypoluxo | organization | find, | tammi, | cluster | play? | mirage | girls | ham | loveless | chan | 2025 | stacy | headed | salad | eclectic | berryz | 2033 | deidre | toi | kansas | restaurants | tristan | ina | leroi | fame | freakbeat | rubalcaba | knockabout | dã©cadas | robyn | genre? | boo | temperance | acoustics | spring | 21:41:08 | spasmolytic | better | death | slept | shark | sonntagskind | ah | sportsdome | perception | roy | timis | hiphop | elephants | reserved | granddaughter | madawaska | kågen | sabo | wins | faust | qatar | bracey | virginia's | notebooks | brunswick | anthology | exiles | order | ufc | exploits | bistro | doi | mauda | pura | chump | riverside | jeremy | germany | womack | mcnamara | methuen | tartine | comics | quantum | vengeance | winter | wenham | black—victini | 04:08:11 | lynn | exira | actress | entertainment | manan | sean | wright | dianne | gunathilake | gradyville | surfs | leoti | mood | forgetting | lentil | restautant | jacqueline | what | outer | pay | connorville | lora's | occoquan | defenestration | pilgrims | hood | person. | chatterjee | belarus | nhl | maltby | tukaram | joanna | found | there's | airi | cutta | spooks | geschwisterliebe | follow | today: | alchemyst: | starting? | reuben | rena's | 1967 | kimberley | ecological | olvey | sixteen | ettrick | pallett | winning | enid | fascility | 20:45:24 | 103rd | waconia | top-5 | pines | balls | kettle | seven-ups | guitar | dutchess | silvester | among | paisley | fest | litchfield | liquor | being | za | tieghem | puthri | intruders | doors | good, | ledoux | meriton | ethiopia | midnights | voisin | holtwood | 00s | javine | almost | pooley | culture | rev-raptor | kelly | spot | built | undressed | happened | portugal | heeft | subcontract | electronica | top-10 | laserlight | portrait | toyan | webley | hamish | targeted | albino | contesting | rosenbaum | danville | belief | sapin | fancy | pianist | banc | meast | sanctuary | watsons | jersey | easton | cash | smoke | nation | wynter | punk's | abori ...
